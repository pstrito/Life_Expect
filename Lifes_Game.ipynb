# %% [markdown]
# Lifes_Game rev 1.0
#
# This program uses the algorith published by qualityhealth.com
# https://www.qualityhealth.com/health-lifestyle-articles/22-ways-predict-your-life-span
#
# NEEDS PERMISSION TO USE ...
#
# It uses 22 different metrics to estimate a persons longevity based on various "characteristics" of a person's life. This is a game and should be viewed as such. The results from using this process should not be viewed as prophetic. No one knows how long they will live except the Lord. (see Job 14:5, Psalm 139:16, Matt 6:27)
#
# Again, no decisions should be made from the results of this game. It is up to the individual user to decide what is best for themselves. Before any changes are made, the appropriate professional should be consulted, NOT this game...
#
# Have fun!!!!

# %%
import pandas as pd
import numpy as np

# %%
# variable assignment
baseline_male = 75
baseline_woman = 81

# %%
# sets up the dataframe df

# creates dictionary to be used to populate the df
init_data = [{'Gender':'NaN', 'Age':'NaN', 'Marital Status':'NaN', 'Education Level':'NaN', 
              'Financial Income': 'NaN', 'Location': 'NaN', 'Family History': 'NaN', 
              'Medical History': 'NaN', 'Weight': 'NaN', 'Smoking Habits': 'NaN', 
              'Drinking Habits': 'Nan', 'Eating Habits': 'NaN', 'Exercise Levels': 'NaN', 
              'Sleeping Habits': 'NaN', 'Safety Habits': 'NaN', 'Sun Exposure': 'NaN',
              'Flossing Habits': 'NaN', 'Stress Management': 'NaN', 'Pets': 'NaN', 
              'Preventative Care': 'NaN', 'Outlook': 'NaN', 'Family & Friends': 'NaN'}]

# creates the df with the appropriate column names
df = pd.DataFrame(init_data, columns = ['Gender', 'Age', 'Marital Status', 'Education Level', 
                             'Financial Income', 'Location', 'Family History', 'Medical History',
                             'Weight', 'Smoking Habits', 'Drinking Habits', 'Eating Habits',
                             'Exercise Levels', 'Sleep Habits', 'Safety Habits', 'Sun Exposure',
                             'Flossing Habits', 'Stress Management', 'Pets', 'Preventative Care',
                             'Outlook', 'Family & Friends'])

# %%
# data input
def input_data(df):
    
    # gender
    print()
    gender = input('What is your birth gender? [Enter "m" for male and "f" for female.]') #Gender
    if gender == 'm':
        df['Gender'] = int(75) #Baseline gender age for male
    else:
        df['Gender'] = int(81) #Baseline gender age for female
    
    # age
    print('\nWhat is your age?')
    print('If you were born between 1901 through 1945 enter a 1?')
    print('If you were born between 1946 through 1959 enter a 2?')
    print('If you were born between 1960 through 1979 enter a 3?')
    print('If you were born between 1980 through 2001 enter a 4?')
    age = input('Enter the correct number. [ 1-4] ')
    if age == '1':
        df['Age'] = int(2)
    elif age == '2':
        df['Age'] = int(0)
    elif age == '3':
        df['Age'] = int(1)
    elif age == '4':
        df['Age'] = int(3)
    
    # married
    print()
    married = input('\nAre you presently married? [Enter either a "y" or "n".]' )
    if married == 'y' and gender == 'm':
        df['Marital Status'] = int(5)
    elif married == 'y' and gender == 'f':
        df['Marital Status'] = int(2)
    else:
        df['Marital Status'] = int(-2)
        
    # educational level
    print()
    edu = input('\nDo you have more than 12 years of education (post high-schoo)? [Enter either a "y" or "n".]')
    if edu == 'y':
        df['Education Level'] = int(2)
    else: 
        df['Education Level'] = int(-2)
        
    # financial income
    print('\nWhat is your income?')
    print('If it is greater than $75,000 per year enter a 1?')
    print('If it is between $50,000 through $74,000 enter a 2?')
    print('If it is between $35,000 through $49,000 enter a 3?')
    print('If it is less than $34,000 enter a 4?')
    fin = input('Enter the correct number. [1-4] \n')
    
    if fin == '1':
        df['Financial Income'] = int(2)
    elif fin == '2':
        df['Financial Income'] = int(1)
    elif fin == '3':
        df['Financial Income'] = int(0)       
    elif fin == '4':
        df['Financial Income'] = int(-1)

    # location
    loc = input('\nHave you lived most of your life in the country (1), city(2) or sububurbs(3)? [Enter 1, 2 or 3]')
    if loc == '1':
        df['Location'] = int(2) #country
    elif location == '2':
        df['Location'] = int(-2) #city
    else:
        df['Location'] = int(0) #suburbs

    # family history
    print()
    fam_hist1 = input('Do you have two or more grandparents that lived to be older that 80 yrs old? [Enter "y" or "n."]')
    fam_hist2 = input('Do you have a parent, sibling or grandparent that died of a heart attack or stroke before 50? [Enter "y" or "n."]')
    fam_hist3 = input('Do you have a parent, sibling or grandparent that died of a heart attack or stroke between 50 and 60? [Enter "y" or "n."]')
    fam_hist4 = input('How many cases of heart disease, diabetes or breast or digestive-system cancer within you parents, siblings or grandparents? ')
    
    df['Family History'] = 0
    
    if fam_hist1 == 'y':
        df['Family History'] = int(4)
        
    if fam_hist2 == 'y' and fam_hist2 == 'n':
        df['Family History'] = df['Family History'] + int(-4)
                      
    if fam_hist3 == 'y':
        df['Family History'] = df['Family History'] + int(-2) 
        
    df['Family History'] = df['Family History'] + int(fam_hist4) * -3 
    
    # medical history
    print()
    med_hist1 = input('Have you been diagnosed with high blood pressure or high cholesterol? [Enter either "y" or "n."]')
    med_hist2 = input('Have you been diagnosed with heart disease, diabetes, cancer or COPD? [Enter either "y" or "n."]')
    
    if med_hist1 == 'y' and med_hist2 == 'n':
        df['Medical History'] = -3
    
    if med_hist1 == 'n' and med_hist2 == 'y':
        df['Medical History'] = -7
        
    if med_hist1 == 'y' and med_hist2 == 'y':
        df['Medical History'] = -10
        
    # weight
    bmi = int(input('Is your BMI less than 25 (enter "1"); 25 to 30 (enter "2"); over 30 (enter "3")')) 
    
    if bmi == 1:
        df['Weight'] = 2
    elif bmi == 2:
        df['Weight'] = -2
    else:
        df['Weight'] = -5
        

    # smoking habits
    print('\nYou do not smoke and are not exposed to second hand smoke? (enter 0)')    
    print('Do you smoke less than one pack a day or exposed to secondhand smoke or smoke cigars or a pipe? (enter 1)')
    print('Do you smoke between one and two packs a day? (enter 2)')
    print('Do you smoke two or more packs a day? (enter 3)' )

    smoke = int(input('Enter a 0, 1, 2, or 3.'))
        
    if smoke == 0:
        df['Smoking Habits'] = 0 
    elif smoke == 1:
        df['Smoking Habits'] = -2
    elif smoke == 2:
        df['Smoking Habits'] = -5
    elif smoke == 3: 
        df['Smoking Habits'] = -8
        
    # drinking habits
    print('\nDo you not drink any alcoholic beverages or generally consume red wine? (enter 0)')    
    print('Do you drink one to three drinks a day? (enter 1)')
    print('Do you drink more than four drinks a day? (enter 2)')
    drink = int(input('Enter a 0, 1, 2.'))
        
    if drink == 0:
        df['Drinking Habits'] = 0 
    elif drink == 1:
        df['Drinking Habits'] = 2
    elif drink == 2:
        df['Drinking Habits'] = -7
    
    # eating habits
    print('\nDo you eat a health diet consisting of of fresh fruit, vegetables, whole grains \nand unsaturated fats? (enter 0)')
    print('Do you eat an unhealthy diet consisting of fast foods, red meat, sugar, and \ntrans or saturated fats? (enter 1) ')
    print('Do you have an average diet that consists of a combination of a healthy and un-healthy, \ndiet? (enter 2)')
    
    diet = int(input('Enter either a 0, 1, or 2,'))
         
    if diet == 0:
        df['Eating Habits'] = 3 
    elif diet == 1:
        df['Eating Habits'] = -3
    elif diet == 2:
        df['Eating Habits'] = 0      
          
    # exercise levels  
    print('\nDo you vigorously exercise 3 or more times in a week? (enter 0)')
    print('Do you moderately exercise 3 or more times in a week? (enter 1) ')
    print('Do you not exercise? (enter 2)')
    
    exercise = int(input('Enter either a 0, 1, or 2,'))
         
    if exercise == 0:
        df['Exercise Levels'] = 5 
    elif exercise == 1:
        df['Exercise Levels'] = 3
    elif exercise == 2:
        df['Exercise Levels'] = -3      
          
    # sleep habits
    print('\nDo you sleep between 6 and 8 hours a night? (enter 0)')
    print('Do you sleep less than 6 hours a night? (enter 1) ')
    print('Do you sleep longer than 8 hours a night? (enter 2)')
    
    sleep = int(input('Enter either a 0, 1, or 2,'))
         
    if sleep == 0:
        df['Sleep Habits'] = 2 
    elif sleep == 1:
        df['Sleep Habits'] = -2
    elif sleep == 2:
        df['Sleep Habits'] = -3      
          
    # safety habits
    print('\nDo you wear your seat belt all of the time? (enter 0)')
    print('Do you wear your seat belt most of the time? (enter 1) ')
    print('Do you wear your seat belt about half of the time? (enter 2)')
    print('Do you wear your seat belt less than half of the time? (enter 3)')
    
    safety = int(input('Enter either a 0, 1, 2, or 3'))
         
    if safety == 0:
        df['Safety Habits'] = 1 
    elif sleep == 1:
        df['Safety Habits'] = 0
    elif sleep == 2:
        df['Safety Habits'] = -1      
    elif sleep == 2:
        df['Safety Habits'] = -2           
          
     # sun exposure
    print('\nDo you always reduce your UV exposure by wearing protective clothing \nstaying out of the sun in midday, and wearing a broad-spectrum sunscreen \nwith an SPF of at least 15?') 
    sun = input('Enter either a "y" or "n."')
     
    if sun == "y":
        df['Sun Exposure'] = 1 
    else:
        df['Sun Exposure'] = -1
        
    # flossing habits
    print('\nDo you floss every day?') 
    floss = input('Enter either a "y" or "n."')
     
    if floss == "y":
        df['Flossing Habits'] = 2
    else:
        df['Flossing Habits'] = -2
    
    # stress managment
    print('\nDoes stress make you angry and grind away at you? (enter 0)')
    print('Does stress motivate you in a positive way? (enter 1)')
    print('Does stress not bother you or you can easily deal with it? (enter 2)')
    
    stress = int(input('Enter either a 0, 1, or 2,'))
         
    if stress == 0:
        df['Stress Management'] = -3 
    elif stress == 1:
        df['Stress Management'] = 3
    elif stress == 2:
        df['Stress Management'] = 0      
          
    # pets
    print('\nDo you own a dog? (enter 0)')
    print('Do you own a cat or any other companion animal? (enter 1) ')
    print('You do not own a pet? (enter 2)')
    
    pet = int(input('Enter either a 0, 1, or 2,'))
         
    if pet == 0:
        df['Pets'] = 3 
    elif pet == 1:
        df['Pets'] = 2
    elif pet == 2:
        df['Pets'] = -2            
          
    # preventative care
    print("\nWas your last doctor's checkup with the last year? (enter 0)")
    print("Was your last doctor's checkup between one and two years ago? (enter 1)")
    print("Was your last doctor's checkup over two years ago? (enter 2)")
    
    preventative = int(input('Enter either a 0, 1, or 2,'))
         
    if preventative == 0:
        df['Preventative Care'] = 3 
    elif preventative == 1:
        df['Preventative Care'] = 2
    elif preventative == 2:
        df['Preventative Care'] = -2          
    
    # outlook
    print("\nAre you an optimistic person? (enter 0)")
    print("Are you a pessimistic person? (enter 1)")
    print("Are you neither optimistic or pessimistic? (enter 2)")     
    out = int(input('(Enter either a 0, 1 or 2.)'))
    
    if out == 0:
        df['Outlook'] = 2 
    elif out == 1:
        df['Outlook'] = -2
    elif out == 2:
        df['Outlook'] = 0      
          
    # family & friends
    print()
    family = input('Do you see close family and friends at least 3 times a week? (enter "y" or "n")')

    if family == "y":
        df['Family & Friends'] = 3
    else:
        df['Family & Friends'] = -2
    
    return df
        
        
print()
df = input_data(df)

df['sum'] = df.sum(axis = 1) #sums all of the columns and adds a column with the total

print('The estimated age is:', df['sum'])
# Out:
# What is your birth gender? [Enter "m" for male and "f" for female.]m
#
# What is your age?
# If you were born between 1901 through 1945 enter a 1?
# If you were born between 1946 through 1959 enter a 2?
# If you were born between 1960 through 1979 enter a 3?
# If you were born between 1980 through 2001 enter a 4?
# Enter the correct number. [ 1-4] 2
#
# Are you presently married? [Enter either a "y" or "n".]y
#
# Do you have more than 12 years of education (post high-schoo)? [Enter either a "y" or "n".]y
#
# What is your income?
# If it is greater than $75,000 per year enter a 1?
# If it is between $50,000 through $74,000 enter a 2?
# If it is between $35,000 through $49,000 enter a 3?
# If it is less than $34,000 enter a 4?
# Enter the correct number. [1-4]
# 1
#
# Have you lived most of your life in the country (1), city(2) or sububurbs(3)? [Enter 1, 2 or 3]1
# Do you have two or more grandparents that lived to be older that 80 yrs old? [Enter "y" or "n."]n
# ...

# %%
df['sum'] = df.sum(axis = 1)

# %%
print(df)
# Out:
#    Gender  Age  Marital Status  Education Level  Financial Income  Location  \
# 0      75    0               5                2                 2         2
#
#    Family History  Medical History  Weight  Smoking Habits  ...  Sleep Habits  \
# 0             -12               -3      -5               0  ...             2
#
#    Safety Habits  Sun Exposure  Flossing Habits  Stress Management  Pets  \
# 0              1             1                2                  0     3
#
#    Preventative Care  Outlook  Family & Friends  sum
# 0                  3        2                 3   86
#
# [1 rows x 23 columns]

# %%
df1 = df
df = df.drop(columns = ['sum'])

# %%
print(df)
# Out:
#    Gender  Age  Marital Status  Education Level  Financial Income  Location  \
# 0      75    0               5                2                 2         2
#
#    Family History  Medical History  Weight  Smoking Habits  ...  \
# 0             -12               -3      -5               0  ...
#
#    Exercise Levels  Sleep Habits  Safety Habits  Sun Exposure  \
# 0                3             2              1             1
#
#    Flossing Habits  Stress Management  Pets  Preventative Care  Outlook  \
# 0                2                  0     3                  3        2
#
#    Family & Friends
# 0                 3
#
# [1 rows x 22 columns]

# %%
# !pip freeze
